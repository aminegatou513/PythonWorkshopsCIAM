# %% [markdown]
# # List Methods :

# %% [markdown]
# ## Append : we use the append method to add an element to the end of a list

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.append("orange")

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ## Extend

# %%
fruits = ['apple', 'banana', 'cherry']
cars = ['Ford', 'BMW', 'Volvo']
fruits.extend(cars)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'Ford', 'BMW', 'Volvo']

# %%
fruits = ['apple', 'banana', 'cherry']
points = (1, 4, 5, 9)
string = "hello"
fruits.extend(points)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 1, 4, 5, 9]

# %% [markdown]
# ## Insert

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.insert(1, "orange")
fruits.insert(1, "strawberry")

# %%
fruits
# Out:
# ['apple', 'strawberry', 'orange', 'banana', 'cherry']

# %% [markdown]
# ## Clear

# %%
fruits = ['apple', 'banana', 'cherry', 'orange']
fruits.clear()

# %%
fruits
# Out:
# []

# %% [markdown]
# ## Copy

# %%
fruits = ['apple', 'banana', 'cherry', 'orange']
x = fruits.copy()

# %%
fruits[2] = 'strawberry'
fruits
# Out:
# ['apple', 'banana', 'strawberry', 'orange']

# %%
x
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %% [markdown]
# ## Count

# %%
fruits = ['apple', 'banana', 'cherry','cherry']
x = fruits.count("cherry")

# %%
x
# Out:
# 2

# %%
points = [1, 4, 2, 9, 7, 8, 9, 3, 1, 9, 9]
x = points.count(9)

# %%
x
# Out:
# 4

# %% [markdown]
# ## Index

# %%
fruits = ['apple', 'banana', 'cherry']
x = fruits.index("apple")

# %%
x
# Out:
# 0

# %%
fruits = [4, 55, 64, 32, 16, 32]
x = fruits.index(32)

# %%
x
# Out:
# 3

# %% [markdown]
# ## Pop

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.pop(1)
# Out:
# 'banana'

# %%
fruits
# Out:
# ['apple', 'cherry']

# %% [markdown]
# ## Remove

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.remove("cherry")

# %%
fruits
# Out:
# ['apple', 'banana']

# %% [markdown]
# ## Reverse

# %%
fruits = ['apple', 'banana', 'cherry']
fruits.reverse()

# %%
fruits
# Out:
# ['cherry', 'banana', 'apple']

# %% [markdown]
# ## Sort

# %%
fruits = ['cherry', 'apple', 'banana']
fruits.sort()

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
fruits.sort(reverse=True)

# %%
fruits
# Out:
# ['cherry', 'banana', 'apple']

# %%
numbers = [2,4,1,9,6,9,7,8,3,1,0]
numbers.sort()

# %%
numbers
# Out:
# [0, 1, 1, 2, 3, 4, 6, 7, 8, 9, 9]

# %% [markdown]
# # Practice :

# %% [markdown]
# ### Exercice 1 :

# %% [markdown]
# Write a Python program to print a specified list after removing the 0th, 4th and 5th elements.
# ![image.png](attachment:image.png)

# %%
color = ['Red', 'Green', 'White', 'Black', 'Pink', 'Yellow']
color = [x for (i,x) in enumerate(color) if i not in (0,4,5)]
print(color)
# Out:
# ['Green', 'White', 'Black']

# %% [markdown]
# ### Exercice 2 :

# %% [markdown]
# Write a Python program to print the numbers of a specified list after removing even numbers from it.

# %%
num = [7,8, 120, 25, 44, 20, 27]
num = [x for x in num if x%2!=0]
print(num)
# Out:
# [7, 25, 27]

# %% [markdown]
# ### Exercice 3 :

# %% [markdown]
# Write a Python program access the index of a list.
# ![image.png](attachment:image.png)

# %%
nums = [5, 15, 35, 8, 98]
for num_index, num_val in enumerate(nums): 
    # enumerate help us looping through the list with the index and its value at THE SAME TIME
    print(num_index, num_val)
# Out:
# 0 5
# 1 15
# 2 35
# 3 8
# 4 98

# %% [markdown]
# ### Exercice 4 :

# %% [markdown]
# Write a Python program to insert an element at a specified position into a given list.
# ![image.png](attachment:image.png)

# %%
myList=['apple','banana',"cherry","orange"]
print(myList)
def add_to_position(liste,position,element):
    liste.insert(position,element)
    return liste

print(add_to_position(myList,2,"mango"))
print(add_to_position(myList,5,"watermelon"))
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'mango', 'cherry', 'orange']
# ['apple', 'banana', 'mango', 'cherry', 'orange', 'watermelon']

# %% [markdown]
# ### Exercice 5 :

# %% [markdown]
# Write a Python program to find the list in a list of lists whose sum of elements is the highest. Go to the editor
# Sample lists: [1,2,3], [4,5,6], [10,11,12], [7,8,9]
# Expected Output: [10, 11, 12]
# ![image.png](attachment:image.png)

# %%
#List of lists : 
num = [[1,2,3], [4,5,6], [10,11,12], [7,8,9]]
sums = []
indexes = []
for index,element in enumerate(num):
    sums.append(sum(element))
    indexes.append(index) # This code prints out the sum of each inner list of our big list and their index
print(sums)
print(indexes)
print(num[sums.index(max(sums))]) 
#The index() method returns the index of the specified element in the list.
#we get the index of max() of list of sums, then we get its index , and print the elments in that index
##METHOD 2 
print("METHOD 2")
num = [[1,2,3], [4,5,6], [10,11,12], [7,8,9]]
print(max(num, key=sum)) # the max function have an attribute key that if its used in iterable elements such as lists
# Out:
# [6, 15, 33, 24]
# [0, 1, 2, 3]
# [10, 11, 12]
# METHOD 2
# [10, 11, 12]

# %%
print("HAPPY LEARNING GUYS")
print("CIAM")
